# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
batters= pd.read_csv('data/mlb-player-stats-Batters.csv')
pitchers= pd.read_csv('data/mlb-player-stats-P.csv')
Arizona_ps=pitchers[(pitchers['Team'] == "SEA")]
Arizona_ps
# Out:
#                Player Team  Age   G  GS  CG  SHO     IP    H  ER    K  BB  HR  \
# 6       Luis Castillo  SEA   31  33  33   0    0  197.0  160  73  219  56  28
# 13      Logan Gilbert  SEA   26  32  32   1    1  190.2  169  79  189  36  29
# 14       George Kirby  SEA   26  31  31   1    0  190.2  179  71  172  19  22
# 77       Bryce Miller  SEA   25  25  25   0    0  131.1  124  63  119  26  18
# 144         Bryan Woo  SEA   24  18  18   0    0   87.2   75  41   93  31  13
# 188        Matt Brash  SEA   25  78   0   0    0   70.2   65  24  107  29   3
# 197       Justin Topa  SEA   33  75   0   0    0   69.0   61  20   61  18   4
# 291       Gabe Speier  SEA   28  69   0   0    0   54.2   47  23   64  11   7
# 327    Marco Gonzales  SEA   32  10  10   0    0   50.0   55  29   34  18   5
# 332      Andres Munoz  SEA   25  52   0   0    0   49.0   40  16   67  22   2
# 340    Tayler Saucedo  SEA   30  52   0   0    0   47.2   41  19   43  23   2
# ...

# %%
batters[batters['Team']=='LAA']
# Out:
#                Player Team Pos  Age    G   AB    R    H  2B  3B  ...  CS  BB  \
# 92      Shohei Ohtani  LAA  DH   29  135  497  102  151  26   8  ...   6  91
# 102     Brandon Drury  LAA  2B   31  125  485   61  127  30   3  ...   2  25
# 120    Hunter Renfroe  LAA  OF   32  126  459   56  111  31   0  ...   0  39
# 161      Luis Rengifo  LAA  2B   27  126  394   55  104  15   4  ...   4  41
# 198       Taylor Ward  LAA  OF   30   97  356   60   90  18   0  ...   2  39
# 237     Mickey Moniak  LAA  OF   25   85  311   35   87  21   2  ...   3   9
# 243        Mike Trout  LAA  OF   32   82  308   54   81  14   1  ...   0  45
# 265         Zach Neto  LAA  SS   23   84  289   38   65  17   0  ...   1  20
# 287       Matt Thaiss  LAA   C   28   95  262   32   56   6   0  ...   0  36
# 303    Mike Moustakas  LAA  3B   35   65  237   22   56   8   0  ...   0   6
# 326       Gio Urshela  LAA  3B   32   62  214   22   64   8   1  ...   2  10
# ...

# %%
from team import *

LA=Team('LAD', batters, pitchers, batting_order_dict['LAD'], batting_order_dict['LAD'])
SEA=Team('SEA', batters, pitchers, batting_order_dict['SEA'], batting_order_dict['SEA'])

# %%
for i in range(9):
    print(LA.batters[i].hit_prob, SEA.batters[i].hit_prob)
# Out:
# 0.3065068493150685 0.26591760299625467
# 0.33124018838304553 0.2504258943781942
# 0.2708333333333333 0.27522935779816515
# 0.21161825726141079 0.25268817204301075
# 0.2607758620689655 0.23244147157190637
# 0.2694610778443114 0.2576
# 0.2619047619047619 0.13043478260869565
# 0.25888324873096447 0.2896551724137931
# 0.23636363636363636 0.22077922077922077
